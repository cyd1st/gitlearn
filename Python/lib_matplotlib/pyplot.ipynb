# %% [markdown]
# # matplotlib.pyplot 的使用示例

# %% [markdown]
# 画函数 y=sin(x) 的图像。

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

# 定义 x 的范围
x = np.linspace(-2 * np.pi, 2 * np.pi, 400)

# 定义函数 y = sin(x)
y = np.sin(x)

# 设置中文字体
plt.rcParams['font.sans-serif'] = ['MiSans']  # 使用字体名称
plt.rcParams['axes.unicode_minus'] = False    # 正确显示负号

# 绘制函数图像
plt.figure(figsize=(8, 6))
plt.plot(x, y, label='y = sin(x)')
plt.title('函数 y = sin(x) 的图像', fontproperties=font_prop)
plt.xlabel('x', fontproperties=font_prop)
plt.ylabel('y', fontproperties=font_prop)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.legend(prop=font_prop)
plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: MiSans
